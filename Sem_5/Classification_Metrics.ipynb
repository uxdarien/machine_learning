# %% [markdown]
# # Clasification

# %%
# import useful libraries
import numpy as np
import matplotlib.pyplot as plt

# import data
from sklearn.datasets import make_classification

# import classifiers
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.neighbors import KNeighborsClassifier as kNN

# Import validation
from sklearn.model_selection import train_test_split

# %%
# we create 100 separable points
X, y = make_classification(n_samples = 5000, n_features=2, n_classes = 3, n_redundant=0, n_informative=2, n_clusters_per_class=1, random_state=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=1)

print(X.shape,y.shape,X_train.shape,X_test.shape,y_train.shape,y_test.shape)

# Plot train / test data
_, axes = plt.subplots(1,2,figsize=(10,5))
axes[0].scatter(X[:,0],X[:,1],c=y,cmap="Paired")
axes[1].scatter(X_train[:,0],X_train[:,1],c=y_train,cmap="BrBG")
axes[1].scatter(X_test[:,0],X_test[:,1],c=y_test,cmap="BrBG", edgecolors="r")
# Out:
# (5000, 2) (5000,) (4000, 2) (1000, 2) (4000,) (1000,)

# %%
'''
    --> Paste your plot_2d_decision_boundaries function here!
'''

# %%
#train linear regression

linear_regression = LinearRegression().fit(X_train, y_train)
print ("m: {0:.4f}, b: {1:.4f}".format(linear_regression.coef_[0], linear_regression.intercept_))

predictions = linear_regression.predict(X_test)
# Out:
# m: -0.3094, b: 1.0069

# %%
models = [ _ , _ , _ ]

_, axes = plt.subplots(1,3, figsize = (20,5))
preds = {}

# fit the models
for _ in _ :
    #
    clf = _
    clf.fit( _ , _ )

    # Plot everything

plt.show()

# %% [markdown]
# ## Metricas de desempeño
#
# Módulo de [Metrics](https://scikit-learn.org/stable/modules/classes.html#module-sklearn.metrics) de sklearn

# %%
from sklearn.metrics import  confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, mean_squared_error,mean_absolute_error
import seaborn as sns

# %%
mse = mean_squared_error(y_test, predictions)
mae = mean_absolute_error(y_test, predictions)
print(f"MSE: {mse:.4f}, MAE: {mae:.4f}")
# Out:
# MSE: 0.2395, MAE: 0.3646

# %%
_, axes = plt.subplots(figsize = (21,4))

# Compute metrics - plot confusion matrix
# for _ in _ :
print ("########----- Results for {0} -----########".format( _ ))
accuracy = accuracy_score( y_test , predictions )
precision = precision_score( y_test , predictions , average = "micro")
recall = recall_score( y_test , predictions , average = "micro")
f1 = f1_score( y_test , predictions , average = "micro")
cm = confusion_matrix( y_test , predictions )
##--------------
print("-- Acc --\t -- Prec --\t -- Rec --\t -- F1 --  ")
print("  {0:.3f}  \t   {1:.3f}  \t   {2:.3f}  \t   {3:.3f}  \t".format(accuracy, precision, recall, f1))
sns.heatmap(cm, cmap = "hot", annot = True, ax = _ )
axes[i].set_title( "_" )
# Out:
# ########----- Results for Figure(2100x400) -----########
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-c8b9062b3b41> in <cell line: 6>()
#       4 # for _ in _ :
#       5 print ("########----- Results for {0} -----########".format( _ ))
# ----> 6 accuracy = accuracy_score( y_test , predictions )
#       7 precision = precision_score( y_test , predictions , average = "micro")
#       8 recall = recall_score( y_test , predictions , average = "micro")
#
# NameError: name 'predictions' is not defined

# %% [markdown]
# ## En datos reales

# %%
# import useful libraries
import numpy as np
import matplotlib.pyplot as plt

# import data
from sklearn.datasets import load_digits

# import classifiers
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier as kNN

# %%
digits = load_digits()
print(digits.data.shape)

plt.imshow(digits.images[0].reshape(8,8), cmap="gray")
# Out:
# (1797, 64)

# %% [markdown]
# Evalúe los distintos algoritmos entrenando con esta base de datos.

# %% [markdown]
# # Regression

# %%
# import useful libraries
import numpy as np
import matplotlib.pyplot as plt

# import data
from sklearn.datasets import make_regression

# import classifiers
from sklearn.linear_model import LinearRegression

# Import validation
from sklearn.model_selection import train_test_split

# %%
X, y = make_regression(n_samples = 1000, n_features = _ , noise = _ , random_state = 1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)


np.random.seed(0)
y_test = y_test + np.random.normal(len(y_test)) * 0.1

# Plot train / test data
_

# %%
# Train a linear regression

# %% [markdown]
# ## Metricas de desempeño
#
# Módulo de [Metrics](https://scikit-learn.org/stable/modules/classes.html#module-sklearn.metrics) de sklearn

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
# Compute MAE and MSE
